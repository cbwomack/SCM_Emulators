# %%
import response_utils
import numpy as np
import matplotlib.pyplot as plt
import xarray as xr
from scipy.optimize import minimize
plt.rcParams['figure.figsize'] = [12, 4]
plt.rcParams.update({'font.size': 16})
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "serif",  # Use a LaTeX-compatible serif font
    "font.serif": ["Computer Modern Roman"],  # Or another LaTeX font
})

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Experiment 4: MESM

# %% [markdown]
# ##### Import MESM data

# %%
MESM_path = '/Volumes/PRO-G40/data/raw/MESM2.2'
exp = '1pctCO2'
exp_path = f'{MESM_path}/{exp}'
forcing_path = f'{exp_path}/forcing'
zonal_temp_path = f'{exp_path}/temperature/zonal'
global_temp_path = f'{exp_path}/temperature/global'

# zonal_temp_ds = xr.open_mfdataset(f'{global_temp_path}', use_cftime=True)
zonal_temp_ds = xr.open_mfdataset(f'{zonal_temp_path}/ZONAL.1%-CO2.2001.23.*.nc')
zonal_temp_ds
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 9
#       6 global_temp_path = f'{exp_path}/temperature/global'
#       8 # zonal_temp_ds = xr.open_mfdataset(f'{global_temp_path}', use_cftime=True)
# ----> 9 zonal_temp_ds = xr.open_mfdataset(f'{zonal_temp_path}/ZONAL.1%-CO2.2001.23.*.nc',data_vars='minimal', coords='minimal')
#      10 zonal_temp_ds
#
# File ~/anaconda3/envs/research/lib/python3.12/site-packages/xarray/backends/api.py:1066, in open_mfdataset(paths, chunks, concat_dim, compat, preprocess, engine, data_vars, coords, combine, parallel, join, attrs_file, combine_attrs, **kwargs)
#    <a href='file:///Users/chriswomack/anaconda3/envs/research/lib/python3.12/site-packages/xarray/backends/api.py?line=1052'>1053</a>     combined = _nested_combine(
# ...

# %%
# Out:
# <xarray.Dataset>
# Dimensions:   (time: 12, lat: 46)
# Coordinates:
#   * time      (time) float32 9.969e+36 9.969e+36 ... 9.969e+36 9.969e+36
#   * lat       (lat) float32 -90.0 -86.0 -82.0 -78.0 ... 78.0 82.0 86.0 90.0
# Data variables:
#     LANDFRAC  (lat) float32 dask.array<chunksize=(46,), meta=np.ndarray>
#     gw        (lat) float32 dask.array<chunksize=(46,), meta=np.ndarray>
#     T2M       (time, lat) float32 dask.array<chunksize=(12, 46), meta=np.ndarray>
#     DT2M      (time, lat) float32 dask.array<chunksize=(12, 46), meta=np.ndarray>
# Attributes:
#     case:     1%-CO2

# %%
print(global_temp_path)
# Out:
# /Volumes/PRO-G40/data/raw/MESM2.2/1pctCO2/temperature/global

# %%
import os
os.path.exists(f'{zonal_temp_path}/ZONAL.1%-CO2.2001.23.0001.nc')
# Out:
# True
