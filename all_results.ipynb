# %%
import numpy as np
import matplotlib.pyplot as plt
import run_all_exp
plt.rcParams['figure.figsize'] = [12, 4]
plt.rcParams.update({'font.size': 16})
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "serif",  # Use a LaTeX-compatible serif font
    "font.serif": ["Computer Modern Roman"],  # Or another LaTeX font
})

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### General Setup

# %%
basis, degree = 'hermite', 1
methods = ['DMD','deconvolve','fit_amp','direct','PS']
experiments = ['3box_uncoup','3box_coup','2box_coup_no_ocean']
scenarios = ['2xCO2','High Emissions','Overshoot']

error_metrics = run_all_exp.run_all(basis, degree, methods, experiments, scenarios, n_modes=3)
# Out:
# Running Experiments...
# /Users/chriswomack/Documents/PhD/Project 1/BudykoSellers.py:320: UserWarning: Simulation has not reached equilibirum (diseq > 1e-3 W m-2)
#   warnings.warn('Simulation has not reached equilibirum (diseq > 1e-3 W m-2)')
# Emulating with DMD...
# Emulating with deconvolve...
# Emulating with fit_amp...
# Emulating with direct...
# Emulating with PS...

# %% [markdown]
# # Exp 1: Three Box Uncoupled
#
# ### High Lat. Ocean:

# %%
regions = ['High Lat. Ocean','Land','Low Lat. Ocean']
exp = experiments[0]
run_all_exp.plot_error_heatmaps(
  error_metrics=error_metrics,
  exp=exp,
  regions=regions,
  methods=methods,
  train_scenarios=scenarios,
  test_scenarios=scenarios,
)
# Out:
# Bbox(x0=0.7663793103448276, y0=0.6535294117647059, x1=0.9000000000000001, y1=0.88)
# Bbox(x0=0.8081263787765492, y0=0.3481219621318873, x1=0.9983332, y1=0.6599951827599565)
# Bbox(x0=0.8081263787765492, y0=0.01864915470252612, x1=0.9983332, y1=0.33416668204213723)

# %% [markdown]
# # Exp 2: Three Box Coupled
#
# ### High Lat. Ocean

# %%
exp = experiments[1]
run_all_exp.plot_error_heatmaps(
  error_metrics=error_metrics,
  exp=exp,
  regions=regions,
  methods=methods,
  train_scenarios=scenarios,
  test_scenarios=scenarios
)
# Out:
# Bbox(x0=0.7663793103448276, y0=0.6535294117647059, x1=0.9000000000000001, y1=0.88)
# Bbox(x0=0.8081263787765492, y0=0.3481219621318873, x1=0.9983332, y1=0.6599951827599565)
# Bbox(x0=0.8081263787765492, y0=0.01864915470252612, x1=0.9983332, y1=0.33416668204213723)

# %% [markdown]
# # Exp 3: Two Box Coupled (only atmosphere)
#
# ### High Lat. Ocean

# %%
exp = experiments[2]
regions = ['Atmosphere','Ocean']
methods = ['DMD','deconvolve','fit_amp','direct']
run_all_exp.plot_error_heatmaps(
  error_metrics=error_metrics,
  exp=exp,
  regions=regions,
  methods=methods,
  train_scenarios=scenarios,
  test_scenarios=scenarios
)
# Out:
# Bbox(x0=0.7315217391304348, y0=0.53, x1=0.9000000000000001, y1=0.88)
# Bbox(x0=0.76136070294947, y0=0.02797373205378918, x1=0.9979164999999999, y1=0.49288816856791395)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[30], line 4
#       2 regions = ['Atmosphere','Ocean']
#       3 methods = ['DMD','deconvolve','fit_amp','direct']
# ----> 4 run_all_exp.plot_error_heatmaps(
#       5   error_metrics=error_metrics,
#       6   exp=exp,
#       7   regions=regions,
#       8   methods=methods,
#       9   train_scenarios=scenarios,
#      10   test_scenarios=scenarios
#      11 )
#
# File ~/Documents/PhD/Project 1/run_all_exp.py:193, in plot_error_heatmaps(error_metrics, exp, regions, methods, train_scenarios, test_scenarios)
#     <a href='file:///Users/chriswomack/Documents/PhD/Project%201/run_all_exp.py?line=190'>191</a> for scen1 in train_scenarios:
#     <a href='file:///Users/chriswomack/Documents/PhD/Project%201/run_all_exp.py?line=191'>192</a>   for scen2 in test_scenarios:
# --> <a href='file:///Users/chriswomack/Documents/PhD/Project%201/run_all_exp.py?line=192'>193</a>     value = error_metrics[method][exp][scen1][scen2][region_idx]
#     <a href='file:///Users/chriswomack/Documents/PhD/Project%201/run_all_exp.py?line=193'>194</a>     if value < min_val:
#     <a href='file:///Users/chriswomack/Documents/PhD/Project%201/run_all_exp.py?line=194'>195</a>       min_val = value
#
# IndexError: index 1 is out of bounds for axis 0 with size 1
